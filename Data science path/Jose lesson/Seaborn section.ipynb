# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Notes

# %% [raw]
# basically, seaborn has been built by matplotlib. so, a lot of matplotlib function and argument are highly realated to seaborn API.

# %% [markdown]
# ### Data

# %%
pwd
# Out:
# 'C:\\Users\\ACER\\Data science path\\Jose lesson'

# %%
df = pd.read_csv('C:\\Users\\ACER\\Data science path\\Jose lesson\\05-Seaborn\\dm_office_sales.csv')
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='salary',y='sales',data=df)
plt.show()

# %% [markdown]
# ### SNS plot params

# %%
plt.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-258ef2d68aad> in <module>
# ----> 1 plt.__version__
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'
