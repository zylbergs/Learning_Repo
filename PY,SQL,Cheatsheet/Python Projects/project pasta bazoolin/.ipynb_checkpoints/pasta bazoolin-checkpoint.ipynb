# %%
#project pasta Bazoolin

class Menu:
    def __init__(self,name,item,start_time,end_time):
        self.name = name
        self.item = item
        self.start_time = start_time 
        self.end_time = end_time 
    
    def __repr__(self):
        representation ="Welcome to pasta Bazoolin and here it is our menu: {menu} available at {start} to {end}".format(menu = self.name, start = self.start_time, end = self.end_time)
        return representation
    
    total_items = []
    
    
    def what_to_purchase(self):
        items = str(input("Select your order: "))
        if items in self.item:
            Menu.total_items.append(items)
            return Menu.total_items
        else:
            return "Please select the correct item"
        
    def unselect_items(self):
        delete = str(input("What item do you want to remove? "))
        if delete in Menu.total_items:
            Menu.total_items.remove(delete)
            return Menu.total_items
        
    def calculate_bill(self,purchased_items):
        purchased_items = Menu.total_items
        total_price = 0
        for each in purchased_items:
            price = self.item[each]
            total_price += price
        return "The total price of your orders are {price}$".format(price = total_price)
    
    def info(self):
        print("This is our {name} menu !!".format(name = self.name))
        for key in self.item:
            print(key + ", the price is "+ str(self.item[key]))

class Franchise:
    def __init__(self,address,menus):
        self.address = address
        self.menus = menus
        
    def __repr__(self):
        return self.address
    
    def available_menus(self, time):
        avail_menu = []
        for menu in self.menus:
            if time >= menu.start_time and time <= menu.end_time:
                avail_menu.append(menu)
        return avail_menu
    
    
class Bussiness:
    def __init__(self,name,franchises):
        self.name = name
        self.franchises = franchises
                
                
        

    
franchises = [flagship_store,new_installment]
menus = [menu1, menu2, menu3, menu4]  
    

menu1 = Menu("brunch",{
  'pancakes': 7.50, 'waffles': 9.00, 'burger': 11.00, 'home fries': 4.50, 'coffee': 1.50, 'espresso': 3.00, 'tea': 1.00, 'mimosa': 10.50, 'orange juice': 3.50
}, 1100, 1600)

menu2 = Menu("early_bird",{
  'salumeria plate': 8.00, 'salad and breadsticks (serves 2, no refills)': 14.00, 'pizza with quattro formaggi': 9.00, 'duck ragu': 17.50, 'mushroom ravioli (vegan)': 13.50, 'coffee': 1.50, 'espresso': 3.00,
},1500,1800)

menu3 = Menu("dinner",{
  'crostini with eggplant caponata': 13.00, 'ceaser salad': 16.00, 'pizza with quattro formaggi': 11.00, 'duck ragu': 19.50, 'mushroom ravioli (vegan)': 13.50, 'coffee': 2.00, 'espresso': 3.00,
},1700,2300)

menu4 = Menu('kids',{
  'chicken nuggets': 6.50, 'fusilli with wild mushrooms': 12.00, 'apple juice': 3.00
},1100,2100)

menu5 = Menu('Arepas menu',{
  'arepa pabellon': 7.00, 'pernil arepa': 8.50, 'guayanes arepa': 8.00, 'jamon arepa': 7.50
},1000,2000)



flagship_store = Franchise("1232 West End Road", menus)

new_installment = Franchise("12 East Mulberry Street", menus)

arepas_place = Franchise("189 Fitzgerald Avenue", menu5)

bussiness1 = Bussiness("Basta Fazoolin' with my Heart", franchises)
bussiness2 = Bussiness("Take a' Arepa", arepas_place)






opening = """Welcome to pasta bazoolin !!
We have special menu in particular hour
please look at our 4 menu.
select between 1-4."""




def opening_inputs():
    print(opening)
    user_input = int(input("what do you want to look out?"))
    if user_input == 1:
        return menu1.info()
    elif user_input ==2:
        return menu2.info()
    elif user_input ==3:
        return menu3.info()
    elif user_input ==4:
        return menu4.info()
    else:
        return opening_inputs()



#menu1.what_to_purchase()
#menu1.what_to_purchase()
#menu1.what_to_purchase()
#menu1.calculate_bill(Menu.total_items)

#menu1.info()
#print(flagship_store.menus)

#print(flagship_store)

#opening_inputs()

flagship_store.available_menus(1200)
# Out:
# [Welcome to pasta Bazoolin and here it is our menu: brunch available at 1100 to 1600,
#  Welcome to pasta Bazoolin and here it is our menu: kids available at 1100 to 2100]
